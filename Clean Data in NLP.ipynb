# %%
import nltk
from nltk.corpus import twitter_samples

# %%
nltk.download("twitter_samples")
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
all_positive_tweet = twitter_samples.strings("positive_tweets.json")
all_negative_tweet = twitter_samples.strings("negative_tweets.json")

# %%
len(all_positive_tweet)
# Out:
# 5000

# %%
len(all_negative_tweet)
# Out:
# 5000

# %%
all_positive_tweet
# Out:
# ['#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)',
#  '@Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!',
#  '@DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!',
#  '@97sides CONGRATS :)',
#  'yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days',
#  '@BhaktisBanter @PallaviRuhail This one is irresistible :)\n#FlipkartFashionFriday http://t.co/EbZ0L2VENM',
#  "We don't like to keep our lovely customers waiting for long! We hope you enjoy! Happy Friday! - LWWF :) https://t.co/smyYriipxI",
#  '@Impatientraider On second thought, there’s just not enough time for a DD :) But new shorts entering system. Sheep must be buying.',
#  'Jgh , but we have to go to Bayan :D bye',
# ...

# %%
all_negative_tweet
# Out:
# ['hopeless for tmr :(',
#  "Everything in the kids section of IKEA is so cute. Shame I'm nearly 19 in 2 months :(",
#  '@Hegelbon That heart sliding into the waste basket. :(',
#  '“@ketchBurning: I hate Japanese call him "bani" :( :(”\n\nMe too',
#  'Dang starting next week I have "work" :(',
#  "oh god, my babies' faces :( https://t.co/9fcwGvaki0",
#  '@RileyMcDonough make me smile :((',
#  '@f0ggstar @stuartthull work neighbour on motors. Asked why and he said hates the updates on search :( http://t.co/XvmTUikWln',
#  'why?:("@tahuodyy: sialan:( https://t.co/Hv1i0xcrL2"',
#  'Athabasca glacier was there in #1948 :-( #athabasca #glacier #jasper #jaspernationalpark #alberta #explorealberta #… http://t.co/dZZdqmf7Cz',
#  "I have a really good m&amp;g idea but I'm never going to meet them :(((",
#  '@Rampageinthebox mare ivan :(',
#  '@SophiaMascardo happy trip, keep safe. see you soon :* :(',
#  "I'm so tired hahahah :(",
# ...

# %%
type(all_negative_tweet)
# Out:
# list

# %%
type(all_negative_tweet[0])
# Out:
# str

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
import string

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

# %%
for i in range(len(all_positive_tweet)):
    all_positive_tweet[i] = re.sub(r"^RT[\s]+", "", all_positive_tweet[i])
    all_positive_tweet[i] = re.sub(r'https?://[^\s\n\r]+', '', all_positive_tweet[i])
    all_positive_tweet[i] = re.sub(r'#', '', all_positive_tweet[i])

# %%
all_positive_tweet
# Out:
# ['FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)',
#  '@Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!',
#  '@DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!',
#  '@97sides CONGRATS :)',
#  'yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days',
#  '@BhaktisBanter @PallaviRuhail This one is irresistible :)\nFlipkartFashionFriday ',
#  "We don't like to keep our lovely customers waiting for long! We hope you enjoy! Happy Friday! - LWWF :) ",
#  '@Impatientraider On second thought, there’s just not enough time for a DD :) But new shorts entering system. Sheep must be buying.',
#  'Jgh , but we have to go to Bayan :D bye',
# ...

# %%
tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)

# %%
all_positive_tweet_tokenize_test = [None] * len(all_positive_tweet)
for i in range(len(all_positive_tweet)):
  all_positive_tweet_tokenize_test[i] = tokenizer.tokenize(all_positive_tweet[i])

# %%
all_positive_tweet_tokenize_test
# Out:
# [['followfriday',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['hey',
#   'james',
#   '!',
#   'how',
#   'odd',
#   ':/',
#   'please',
#   'call',
#   'our',
#   'contact',
#   'centre',
#   'on',
#   '02392441234',
#   'and',
#   'we',
#   'will',
#   'be',
#   'able',
#   'to',
#   'assist',
#   'you',
#   ':)',
#   'many',
#   'thanks',
#   '!'],
#  ['we',
#   'had',
#   'a',
#   'listen',
#   'last',
#   'night',
#   ':)',
#   'as',
#   'you',
#   'bleed',
#   'is',
#   'an',
#   'amazing',
#   'track',
#   '.',
#   'when',
#   'are',
#   'you',
#   'in',
#   'scotland',
#   '?',
#   '!'],
#  ['congrats', ':)'],
#  ['yeaaah',
#   'yipppy',
#   '!',
#   '!',
#   '!',
#   'my',
#   'accnt',
#   'verified',
#   'rqst',
#   'has',
#   'succeed',
#   'got',
#   'a',
#   'blue',
#   'tick',
#   'mark',
#   'on',
#   'my',
#   'fb',
#   'profile',
#   ':)',
#   'in',
#   '15',
# ...

# %%
all_positive_tweet_tokenize = []
for i in range(len(all_positive_tweet)):
  all_positive_tweet_tokenize.append(tokenizer.tokenize(all_positive_tweet[i]))

# %%
all_positive_tweet_tokenize
# Out:
# [['followfriday',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['hey',
#   'james',
#   '!',
#   'how',
#   'odd',
#   ':/',
#   'please',
#   'call',
#   'our',
#   'contact',
#   'centre',
#   'on',
#   '02392441234',
#   'and',
#   'we',
#   'will',
#   'be',
#   'able',
#   'to',
#   'assist',
#   'you',
#   ':)',
#   'many',
#   'thanks',
#   '!'],
#  ['we',
#   'had',
#   'a',
#   'listen',
#   'last',
#   'night',
#   ':)',
#   'as',
#   'you',
#   'bleed',
#   'is',
#   'an',
#   'amazing',
#   'track',
#   '.',
#   'when',
#   'are',
#   'you',
#   'in',
#   'scotland',
#   '?',
#   '!'],
#  ['congrats', ':)'],
#  ['yeaaah',
#   'yipppy',
#   '!',
#   '!',
#   '!',
#   'my',
#   'accnt',
#   'verified',
#   'rqst',
#   'has',
#   'succeed',
#   'got',
#   'a',
#   'blue',
#   'tick',
#   'mark',
#   'on',
#   'my',
#   'fb',
#   'profile',
#   ':)',
#   'in',
#   '15',
# ...

# %% [markdown]
# # Remove stop words and punctuations

# %%
stopwords_english = stopwords.words("english")

print("Stop Words")
print(stopwords_english)

print()
print(string.punctuation)
# Out:
# Stop Words
# ...

# %%
for i in range(len(all_positive_tweet_tokenize)):
    all_positive_tweet_tokenize[i] = [word for word in all_positive_tweet_tokenize[i] if word not in stopwords_english]

# %%
all_positive_tweet_tokenize
# Out:
# [['followfriday', 'top', 'engaged', 'members', 'community', 'week', ':)'],
#  ['hey',
#   'james',
#   '!',
#   'odd',
#   ':/',
#   'please',
#   'call',
#   'contact',
#   'centre',
#   '02392441234',
#   'able',
#   'assist',
#   ':)',
#   'many',
#   'thanks',
#   '!'],
#  ['listen',
#   'last',
#   'night',
#   ':)',
#   'bleed',
#   'amazing',
#   'track',
#   '.',
#   'scotland',
#   '?',
#   '!'],
#  ['congrats', ':)'],
#  ['yeaaah',
#   'yipppy',
#   '!',
#   '!',
#   '!',
#   'accnt',
#   'verified',
#   'rqst',
#   'succeed',
#   'got',
#   'blue',
#   'tick',
#   'mark',
#   'fb',
#   'profile',
#   ':)',
#   '15',
#   'days'],
#  ['one', 'irresistible', ':)', 'flipkartfashionfriday'],
#  ['like',
#   'keep',
#   'lovely',
#   'customers',
#   'waiting',
#   'long',
#   '!',
#   'hope',
#   'enjoy',
#   '!',
#   'happy',
#   'friday',
#   '!',
#   '-',
#   'lwwf',
#   ':)'],
#  ['second',
#   'thought',
#   ',',
#   '’',
#   'enough',
#   'time',
#   'dd',
#   ':)',
# ...

# %%
import string

all_positive_tweet_tokenize_clean = []

# Iterate over each string in all_positive_tweet_tokenize
for i in range(len(all_positive_tweet_tokenize)): 
    # Remove punctuation from each string and append to all_positive_tweet_tokenize_clean
    all_positive_tweet_tokenize_clean.append([''.join(char for char in s if char not in string.punctuation) for s in all_positive_tweet_tokenize[i]])

# Print the cleaned list
print(all_positive_tweet_tokenize_clean)
# Out:
# [['followfriday', 'top', 'engaged', 'members', 'community', 'week', ''], ['hey', 'james', '', 'odd', '', 'please', 'call', 'contact', 'centre', '02392441234', 'able', 'assist', '', 'many', 'thanks', ''], ['listen', 'last', 'night', '', 'bleed', 'amazing', 'track', '', 'scotland', '', ''], ['congrats', ''], ['yeaaah', 'yipppy', '', '', '', 'accnt', 'verified', 'rqst', 'succeed', 'got', 'blue', 'tick', 'mark', 'fb', 'profile', '', '15', 'days'], ['one', 'irresistible', '', 'flipkartfashionfriday'], ['like', 'keep', 'lovely', 'customers', 'waiting', 'long', '', 'hope', 'enjoy', '', 'happy', 'friday', '', '', 'lwwf', ''], ['second', 'thought', '', '’', 'enough', 'time', 'dd', '', 'new', 'shorts', 'entering', 'system', '', 'sheep', 'must', 'buying', ''], ['jgh', '', 'go', 'bayan', 'D', 'bye'], ['act', 'mischievousness', '', 'calling', 'etl', 'layer', 'inhouse', 'warehousing', 'app', 'katamari', '', 'well', '…', 'name', 'implies', 'p', ''], ['followfriday', 'top', 'influencers', 'community
# ...

# %%
stemmer = PorterStemmer()

# Create an empty list to store the stems
tweets_stem = []

# Iterate over each list of strings in all_positive_tweet_tokenize_clean
for word_list in all_positive_tweet_tokenize_clean:
    # Iterate over each string in the list
    for word in word_list:
        # Stem the word and append to tweets_stem
        stem_word = stemmer.stem(word)
        tweets_stem.append(stem_word)

# %%
tweets_stem
# Out:
# ['followfriday',
#  'top',
#  'engag',
#  'member',
#  'commun',
#  'week',
#  '',
#  'hey',
#  'jame',
#  '',
#  'odd',
#  '',
#  'pleas',
#  'call',
#  'contact',
#  'centr',
#  '02392441234',
#  'abl',
#  'assist',
#  '',
#  'mani',
#  'thank',
#  '',
#  'listen',
#  'last',
#  'night',
#  '',
#  'bleed',
#  'amaz',
#  'track',
#  '',
#  'scotland',
#  '',
#  '',
#  'congrat',
#  '',
#  'yeaaah',
#  'yipppi',
#  '',
#  '',
#  '',
#  'accnt',
#  'verifi',
#  'rqst',
#  'succeed',
#  'got',
#  'blue',
#  'tick',
#  'mark',
#  'fb',
#  'profil',
#  '',
#  '15',
#  'day',
#  'one',
#  'irresist',
#  '',
#  'flipkartfashionfriday',
#  'like',
#  'keep',
#  'love',
#  'custom',
#  'wait',
#  'long',
#  '',
#  'hope',
#  'enjoy',
#  '',
#  'happi',
#  'friday',
#  '',
#  '',
#  'lwwf',
#  '',
#  'second',
#  'thought',
#  '',
#  '’',
#  'enough',
#  'time',
#  'dd',
#  '',
#  'new',
#  'short',
#  'enter',
#  'system',
#  '',
#  'sheep',
#  'must',
#  'buy',
#  '',
#  'jgh',
#  '',
# ...
